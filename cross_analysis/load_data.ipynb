# %%
import pandas as pd

root = "../full_data/"
header = ['Source','toxicity','severe_toxicity','obscene','threat','insult','identity_attack']
dtype = {'Source':"string",'toxicity':float,'severe_toxicity':float,'obscene':float,'threat':float,'insult':float,'identity_attack':float}

# %%
df_inst = pd.read_csv(root + "inst_score.csv", header=None, skiprows=1, names=header, low_memory=False)
df_reddit = pd.read_csv(root + "reddit_score.csv", header=None, skiprows=229952, names=header)
df_so = pd.read_csv(root + "stackOF_answers_score.csv", header=None, skiprows=1, names=header, low_memory=False)
df_twitter = pd.read_csv(root + "twitter_score.csv", header=None, skiprows=1, names=header, low_memory=False)

# %%
df_inst=df_inst.drop('Source', axis=1)
df_reddit=df_reddit.drop('Source', axis=1)
df_so=df_so.drop('Source', axis=1)
df_twitter=df_twitter.drop('Source', axis=1)

# %%
df=(df_inst.gt(0.5).sum() / df_inst.shape[0]).to_frame().T
df
# Out:
#    toxicity  severe_toxicity   obscene    threat    insult  identity_attack
# 0   0.01806         0.000034  0.007481  0.000157  0.001973         0.000247

# %%
df_inst.describe()
# Out:
#            toxicity  severe_toxicity       obscene        threat
# count  1.117312e+06     1.117312e+06  1.117312e+06  1.117312e+06  \
# mean   3.639993e-02     5.802972e-04  1.010017e-02  6.536928e-04
# std    1.149737e-01     8.258447e-03  7.342841e-02  1.106828e-02
# min    5.000000e-04     8.000000e-05  1.400000e-04  8.000000e-05
# 25%    1.260000e-03     1.000000e-04  1.900000e-04  1.200000e-04
# 50%    4.200000e-03     1.100000e-04  3.200000e-04  1.300000e-04
# 75%    1.683000e-02     1.200000e-04  8.100000e-04  2.200000e-04
# max    9.989600e-01     7.399400e-01  9.954100e-01  8.815300e-01
#
#              insult  identity_attack
# count  1.117312e+06     1.117312e+06
# mean   5.008774e-03     1.054489e-03
# std    3.945060e-02     1.440617e-02
# min    1.600000e-04     1.200000e-04
# 25%    1.900000e-04     1.500000e-04
# 50%    2.800000e-04     1.800000e-04
# 75%    7.100000e-04     2.800000e-04
# max    9.825500e-01     9.147700e-01

# %%
df_reddit.describe()
# Out:
#            toxicity  severe_toxicity       obscene        threat
# count  2.814208e+06     2.814208e+06  2.814208e+06  2.814208e+06  \
# mean   1.020356e-01     5.722498e-03  6.635959e-02  2.632257e-03
# std    2.557978e-01     3.348364e-02  2.169705e-01  2.977271e-02
# min    4.700000e-04     7.000000e-05  1.300000e-04  7.000000e-05
# 25%    7.100000e-04     1.000000e-04  1.800000e-04  1.100000e-04
# 50%    1.220000e-03     1.100000e-04  2.000000e-04  1.200000e-04
# 75%    1.631000e-02     1.300000e-04  7.500000e-04  2.000000e-04
# max    9.992200e-01     8.988800e-01  9.969900e-01  9.248400e-01
#
#              insult  identity_attack
# count  2.814208e+06     2.814208e+06
# mean   3.121917e-02     3.872992e-03
# std    1.254056e-01     3.513255e-02
# min    1.500000e-04     1.100000e-04
# 25%    1.800000e-04     1.400000e-04
# 50%    2.000000e-04     1.500000e-04
# 75%    7.300000e-04     2.900000e-04
# max    9.878800e-01     9.577700e-01

# %%
df_so.describe()
# Out:
#            toxicity  severe_toxicity       obscene        threat
# count  2.014464e+06     2.014464e+06  2.014464e+06  2.014464e+06  \
# mean   2.375741e-03     1.081204e-04  4.079492e-04  1.367959e-04
# std    1.351502e-02     1.088885e-04  6.526752e-03  1.428909e-03
# min    5.100000e-04     8.000000e-05  1.500000e-04  8.000000e-05
# 25%    7.700000e-04     1.000000e-04  1.800000e-04  1.100000e-04
# 50%    9.500000e-04     1.100000e-04  1.900000e-04  1.200000e-04
# 75%    1.420000e-03     1.100000e-04  2.200000e-04  1.200000e-04
# max    9.829700e-01     4.870000e-02  9.426000e-01  5.590600e-01
#
#              insult  identity_attack
# count  2.014464e+06     2.014464e+06
# mean   2.593929e-04     1.458979e-04
# std    2.758991e-03     1.465626e-04
# min    1.600000e-04     1.200000e-04
# 25%    1.800000e-04     1.300000e-04
# 50%    1.800000e-04     1.400000e-04
# 75%    2.000000e-04     1.400000e-04
# max    9.179800e-01     1.356400e-01

# %%
df_twitter.describe()
# Out:
#             toxicity  severe_toxicity        obscene         threat
# count  900037.000000    900037.000000  900037.000000  900037.000000  \
# mean        0.078443         0.003204       0.037291       0.002001
# std         0.214599         0.025475       0.160540       0.025761
# min         0.000490         0.000080       0.000140       0.000080
# 25%         0.000820         0.000100       0.000180       0.000110
# 50%         0.001710         0.000110       0.000210       0.000120
# 75%         0.017500         0.000130       0.000780       0.000190
# max         0.999110         0.855720       0.996900       0.920640
#
#               insult  identity_attack
# count  900037.000000    900037.000000
# mean        0.020775         0.003978
# std         0.102454         0.043212
# min         0.000160         0.000120
# 25%         0.000180         0.000140
# 50%         0.000210         0.000150
# 75%         0.000700         0.000270
# max         0.988070         0.957620
